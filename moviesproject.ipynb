# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install requests
# Out:
# ...
#                                               0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB 1.7 MB/s eta 0:00:00
# ...
#                                               0.0/96.6 kB ? eta -:--:--
#      -------------------------                61.4/96.6 kB 1.7 MB/s eta 0:00:01
#      --------------------------------------   92.2/96.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 96.6/96.6 kB 918.3 kB/s eta 0:00:00
# ...
#                                               0.0/123.6 kB ? eta -:--:--
#      ---------                               30.7/123.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------               81.9/123.6 kB 1.1 MB/s eta 0:00:01
#      -----------------------------------  122.9/123.6 kB 901.1 kB/s eta 0:00:01
#      ------------------------------------ 123.6/123.6 kB 726.8 kB/s eta 0:00:00
# ...
#                                               0.0/157.0 kB ? eta -:--:--
# ...

# %%
import pandas as pd
import requests

# %%
storedata=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page=1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 storedata=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page=1')
#
# NameError: name 'requests' is not defined

# %%
data=storedata.json()
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data=storedata.json()
#       2 data
#
# NameError: name 'storedata' is not defined

# %%
moviedf=pd.DataFrame(storedata.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
moviedf
# Out:
#          id                                        title  \
# 0    455476                        Knights of the Zodiac
# 1    385687                                       Fast X
# 2    447365               Guardians of the Galaxy Vol. 3
# 3    254128                                  San Andreas
# 4    445651                            The Darkest Minds
# 5    406563                      Insidious: The Last Key
# 6    569094          Spider-Man: Across the Spider-Verse
# 7    603692                         John Wick: Chapter 4
# 8    502356                  The Super Mario Bros. Movie
# 9    667538             Transformers: Rise of the Beasts
# 10    47964                       A Good Day to Die Hard
# 11   976573                                    Elemental
# 12   614479                      Insidious: The Red Door
# 13   664767    Mortal Kombat Legends: Scorpion's Revenge
# 14  1103825                War of the Worlds: The Attack
# ...

# %%
moviedf.to_csv("G:\data enginner project\movie_population_api\movie_population2.csv")

# %%
moviedf.nunique()
# Out:
# id              20
# title           20
# overview        20
# release_date    20
# popularity      20
# vote_average    16
# vote_count      20
# dtype: int64

# %%
dff=pd.DataFrame()
dff
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,200):
    storedata=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page={}'.format(i))
    tempdata=pd.DataFrame(storedata.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    #df_data = dff.concat(tempdata,ignore_index=True)
    dff = pd.concat([tempdata, pd.DataFrame(['results'])], ignore_index=True)

# %%
dff
# Out:
#            id                                              title  \
# 0    463116.0                                The Stolen Princess
# 1      1255.0                                           The Host
# 2    334533.0                                  Captain Fantastic
# 3     21316.0                                     Leroy & Stitch
# 4    921355.0                                           Assassin
# 5    814340.0                                Cha Cha Real Smooth
# 6       535.0                                         Flashdance
# 7        90.0                                  Beverly Hills Cop
# 8    335778.0                                              Risen
# 9     16664.0                           All About Lily Chou-Chou
# 10   949977.0                                           X-Deal 2
# 11   560050.0                                      Over the Moon
# 12    44730.0  One Piece: Giant Mecha Soldier of Karakuri Castle
# ...

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,400):
    storedata=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page={}'.format(i))
    tempdata1=pd.DataFrame(storedata.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    #df_data = df1.append(tempdata1,ignore_index=True)
    df = pd.concat([df1, pd.DataFrame(['results'])], ignore_index=True)

# %%
df_data
# Out:
#           id                    title  \
# 0    10295.0          Miami Supercops
# 1   639557.0            Cliff Walkers
# 2    15573.0              The Cowboys
# 3   557946.0               Last Looks
# 4   424488.0             Megan Leavey
# 5     4241.0                Visitor Q
# 6   575769.0                      4x4
# 7     4174.0               Spellbound
# 8    32043.0             The Guardian
# 9   184219.0                  Pee Mak
# 10   19084.0  Johnson Family Vacation
# 11   10447.0                No Escape
# 12  944152.0                Chokehold
# 13  411976.0                Novitiate
# 14  309886.0             Blood Father
# 15   11093.0    House of Sand and Fog
# 16  134597.0           The Collection
# 17    3509.0         A Scanner Darkly
# 18   17961.0                  Torment
# 19    9327.0      The Nutty Professor
# 20       NaN                      NaN
#
#                                              overview release_date  \
# ...

# %%
storedata1=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page=2')

# %%
moviedff=pd.DataFrame(storedata.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
moviedff
# Out:
#          id                                        title  \
# 0    455476                        Knights of the Zodiac
# 1    385687                                       Fast X
# 2    447365               Guardians of the Galaxy Vol. 3
# 3    254128                                  San Andreas
# 4    445651                            The Darkest Minds
# 5    406563                      Insidious: The Last Key
# 6    569094          Spider-Man: Across the Spider-Verse
# 7    603692                         John Wick: Chapter 4
# 8    502356                  The Super Mario Bros. Movie
# 9    667538             Transformers: Rise of the Beasts
# 10    47964                       A Good Day to Die Hard
# 11   976573                                    Elemental
# 12   614479                      Insidious: The Red Door
# 13   664767    Mortal Kombat Legends: Scorpion's Revenge
# 14  1103825                War of the Worlds: The Attack
# ...

# %%
df3=pd.DataFrame()
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for j in range(1,500):
    storedata1=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=b375209d79c0875d0df3a3d9f382d0a8&language=en-US&page={}'.format(j))
    moviedff1=pd.DataFrame(storedata1.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    #df3 =df3.append(moviedff1,ignore_index=True)
    df3 = pd.concat([df3, moviedff1], ignore_index=True)

# %%
df3
# Out:
#              id                                title  \
# 0       30827.0                  Deep Throat Part II
# 1       68737.0                          Seventh Son
# 2        1417.0                      Pan's Labyrinth
# 3      617502.0                                 Jolt
# 4         251.0                                Ghost
# ...         ...                                  ...
# 21916    9357.0                       One Hour Photo
# 21917  865140.0                       Chilangolandia
# 21918     409.0                  The English Patient
# 21919  119900.0  D'Artagnan and the Three Musketeers
# 21920   37498.0                            Knock Off
#
#                                                 overview release_date  \
# 0      Nurse Linda Lovelace works for libidinous sex ...   1974-02-01
# 1      John Gregory, who is a seventh son of a sevent...   2014-12-12
# 2      Living with her tyrannical stepfather in a new...   2006-10-10
# ...

# %%
df3.shape
# Out:
# (21921, 8)

# %%
df3.to_csv("G:\data enginner project\movie_population_api\movie_population.csv")
